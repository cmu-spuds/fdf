# %%
import datasets

# %%
ds = datasets.load_dataset("fdf.py")
# Out:
# /home/meeko/miniconda3/envs/hf/lib/python3.11/site-packages/datasets/load.py:929: FutureWarning: The repository for fdf contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at fdf.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'landmarks', 'bbox', 'metadata'],
#         num_rows: 241982
#     })
#     validation: Dataset({
#         features: ['image', 'landmarks', 'bbox', 'metadata'],
#         num_rows: 6531
#     })
# })

# %%
ds['train'][0]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
ds.push_to_hub("logasja/FDF", set_default=True)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/49 [00:00<?, ?ba/s]
